# %%
#variables vax's rand (1977) 
n = 10000  #cant de muestras
m = 2**32  # mod 
seed = 7 #semilla
a = 69069   #multiplicador
c = 7   #incremento

# %%
numeros = []
x = seed
for _ in range(n):
    x = (a*x + c) % m
    numeros.append(x/m)

# %%
numeros
# Out:
# [0.00011257128790020943,
#  0.7751862856093794,
#  0.34156075585633516,
#  0.2598462428431958,
#  0.3201469383202493,
#  0.2288828429300338,
#  0.709078336134553,
#  0.33159847906790674,
#  0.17535074288025498,
#  0.30045999796129763,
#  0.47159919049590826,
#  0.8844883635174483,
#  0.7267797882668674,
#  0.9531958058942109,
#  0.2811173088848591,
#  0.4914073699619621,
#  0.015635904390364885,
#  0.9562803397420794,
#  0.32678564731031656,
#  0.7578740778844804,
#  0.6046854048036039,
#  0.016224381746724248,
#  0.601822866126895,
#  0.3035405201371759,
#  0.24018535623326898,
#  0.36236967728473246,
#  0.5112403808161616,
#  0.8618625930976123,
#  0.9874426606111228,
#  0.6771257512737066,
#  0.3985147252678871,
#  0.013559529324993491,
#  0.5431309496052563,
#  0.5115582870785147,
#  0.819330227561295,
#  0.31948743271641433,
#  0.6774902916513383,
#  0.5769540679175407,
#  0.6405169982463121,
#  0.8685518761631101,
#  0.009534711483865976,
#  0.5529874807689339,
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(numeros, bins=10, edgecolor='black')
plt.title('Histograma de random_numbers')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()
